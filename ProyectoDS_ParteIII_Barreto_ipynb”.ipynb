# %% [markdown]
# <a href="https://colab.research.google.com/github/Karenab00/DataScience/blob/main/ProyectoDS_ParteIII_Barreto_ipynb%E2%80%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Este estudio analiza un conjunto de datos sobre el riesgo financiero relacionado con la aprobación de préstamos, que contiene información crucial sobre los solicitantes y sus características financieras. El dataset incluye diversas variables, como la fecha de solicitud, edad, ingreso anual, puntuación de solvencia crediticia y estado de empleo, que ofrecen una visión integral del perfil del solicitante. También se consideran factores como el nivel de educación, experiencia laboral, monto del préstamo solicitado y la duración del mismo, junto con detalles sobre el estado civil, número de dependientes y propiedad de la vivienda.
#
# Además, se incorporan métricas financieras, como los pagos de deuda mensuales, la tasa de utilización de tarjetas de crédito y la relación deuda-ingreso, proporcionando un panorama claro de la salud financiera del solicitante. El historial de quiebras, el comportamiento de pago anterior y la duración del historial crediticio son esenciales para evaluar el riesgo asociado con la aprobación del préstamo.
#
# Este análisis busca identificar patrones y relaciones significativas entre las características de los solicitantes y el estado de aprobación de los préstamos, así como entender cómo diferentes variables afectan la decisión crediticia. A través de esta investigación, se pretende proporcionar información valiosa para entidades financieras en la toma de decisiones más informadas y justas al evaluar solicitudes de préstamos, contribuyendo así a una gestión de riesgos más efectiva y equitativa en el sector financiero.

# %%
# ApplicationDate: Fecha de solicitud de préstamo
# Age: Edad del solicitante
# AnnualIncome: Ingreso anual
# CreditScore: Puntuación de crédito
# EmploymentStatus: Situación laboral
# EducationLevel: Nivel educativo más alto alcanzado
# Experience: Experiencia laboral
# LoanAmount: Monto solicitado del préstamo
# LoanDuration: Período de reembolso del préstamo
# MaritalStatus: Estado civil del solicitante
# NumberOfDependents: Número de dependientes
# HomeOwnershipStatus: Tipo de propiedad de vivienda
# MonthlyDebtPayments: Pagos de deuda mensuales
# CreditCardUtilizationRate: Porcentaje de uso de la tarjeta de crédito
# NumberOfOpenCreditLines: Líneas de crédito activas
# NumberOfCreditInquiries: Conteo de verificaciones de crédito
# DebtToIncomeRatio: Proporción de deuda a ingresos
# BankruptcyHistory: Historial de quiebras
# LoanPurpose: Razón del préstamo
# PreviousLoanDefaults: Incumplimientos de préstamos anteriores
# PaymentHistory: Comportamiento de pagos pasados
# LengthOfCreditHistory: Duración del historial crediticio
# SavingsAccountBalance: Saldo de la cuenta de ahorros
# CheckingAccountBalance: Fondos de la cuenta corriente
# TotalAssets: Total de activos
# TotalLiabilities: Total de deudas
# MonthlyIncome: Ingreso mensual
# UtilityBillsPaymentHistory: Registro de pagos de servicios públicos
# JobTenure: Duración en el trabajo
# NetWorth: Patrimonio neto
# BaseInterestRate: Tasa de interés inicial
# InterestRate: Tasa de interés aplicada
# MonthlyLoanPayment: Pago mensual del préstamo
# TotalDebtToIncomeRatio: Relación total de deuda a ingresos
# LoanApproved: Estado de aprobación del préstamo
# RiskScore: Puntuación de riesgo

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive

# %%
df_prestamos = pd.read_csv('/content/drive/MyDrive/datasc/Riesgo financiero para la aprobacion de prestamos.csv')
df_prestamos
# Out:
#       ApplicationDate  Age  AnnualIncome  CreditScore EmploymentStatus  \
# 0          2018-01-01   45         39948          617         Employed
# 1          2018-01-02   38         39709          628         Employed
# 2          2018-01-03   47         40724          570         Employed
# 3          2018-01-04   58         69084          545         Employed
# 4          2018-01-05   37        103264          594         Employed
# ...               ...  ...           ...          ...              ...
# 19995      2072-09-29   44         30180          587         Employed
# 19996      2072-09-30   56         49246          567         Employed
# 19997      2072-10-01   44         48958          645         Employed
# 19998      2072-10-02   60         41025          560         Employed
# 19999      2072-10-03   20         53227          574         Employed
#
#       EducationLevel  Experience  LoanAmount  LoanDuration MaritalStatus  ...  \
# 0             Master          22       13152            48       Married  ...
# 1          Associate          15       26045            48        Single  ...
# 2           Bachelor          26       17627            36       Married  ...
# 3        High School          34       37898            96        Single  ...
# 4          Associate          17        9184            36       Married  ...
# ...              ...         ...         ...           ...           ...  ...
# 19995    High School          19       24521            36       Married  ...
# 19996      Associate          33       25818            36       Married  ...
# 19997       Bachelor          20       37033            72       Married  ...
# 19998    High School          36       14760            72       Married  ...
# 19999      Associate           0       32055            48       Married  ...
#
#        MonthlyIncome UtilityBillsPaymentHistory  JobTenure  NetWorth  \
# 0        3329.000000                   0.724972         11    126928
# 1        3309.083333                   0.935132          3     43609
# 2        3393.666667                   0.872241          6      5205
# 3        5757.000000                   0.896155          5     99452
# 4        8605.333333                   0.941369          5    227019
# ...              ...                        ...        ...       ...
# 19995    2515.000000                   0.826217          1     55327
# 19996    4103.833333                   0.816618          3     64002
# 19997    4079.833333                   0.887216          3    103663
# 19998    3418.750000                   0.843787          5     10600
# 19999    4435.583333                   0.853801          5     41372
#
#        BaseInterestRate  InterestRate  MonthlyLoanPayment  \
# 0              0.199652      0.227590          419.805992
# 1              0.207045      0.201077          794.054238
# 2              0.217627      0.212548          666.406688
# 3              0.300398      0.300911         1047.506980
# 4              0.197184      0.175990          330.179140
# ...                 ...           ...                 ...
# 19995          0.216021      0.195574          905.767712
# 19996          0.227318      0.199168          958.395633
# 19997          0.229533      0.226766          945.427454
# 19998          0.249760      0.264873          411.168284
# 19999          0.240055      0.242693         1049.830407
#
#        TotalDebtToIncomeRatio LoanApproved  RiskScore
# 0                    0.181077            0       49.0
# 1                    0.389852            0       52.0
# 2                    0.462157            0       52.0
# 3                    0.313098            0       54.0
# 4                    0.070210            1       36.0
# ...                       ...          ...        ...
# 19995                0.627741            0       55.0
# 19996                0.334418            0       54.0
# 19997                0.357227            0       45.0
# 19998                0.408678            0       59.0
# 19999                0.298006            0       59.0
#
# [20000 rows x 36 columns]

# %%
#verifico los nulos
df_prestamos.isnull().sum()
# Out:
# ApplicationDate               0
# Age                           0
# AnnualIncome                  0
# CreditScore                   0
# EmploymentStatus              0
# EducationLevel                0
# Experience                    0
# LoanAmount                    0
# LoanDuration                  0
# MaritalStatus                 0
# NumberOfDependents            0
# HomeOwnershipStatus           0
# MonthlyDebtPayments           0
# CreditCardUtilizationRate     0
# NumberOfOpenCreditLines       0
# NumberOfCreditInquiries       0
# DebtToIncomeRatio             0
# BankruptcyHistory             0
# LoanPurpose                   0
# PreviousLoanDefaults          0
# PaymentHistory                0
# LengthOfCreditHistory         0
# SavingsAccountBalance         0
# CheckingAccountBalance        0
# TotalAssets                   0
# TotalLiabilities              0
# MonthlyIncome                 0
# UtilityBillsPaymentHistory    0
# JobTenure                     0
# NetWorth                      0
# BaseInterestRate              0
# InterestRate                  0
# MonthlyLoanPayment            0
# TotalDebtToIncomeRatio        0
# LoanApproved                  0
# RiskScore                     0
# dtype: int64

# %%
sns.set(style="whitegrid")

# %% [markdown]
# #Grafico de torta donde representa la distribucion de los estados civiles de los clientes (1VAR)

# %%
fig, ax = plt.subplots(figsize=(10, 7))
MaritalStatus = df_prestamos['MaritalStatus'].value_counts()
ax.pie(MaritalStatus, labels=MaritalStatus.index, autopct='%1.1f%%', startangle=90)
ax.set_title('Distribución de Estado civil de los clientes')
plt.show()

# %% [markdown]
# Podemos notar en este grafico de tortas, que la mayoria de solicitantes son personas casadas. Esto puede tener muchas respuestas relacionadas al motivo del prestamo. Tambien se puede notar que hay un porcentaje muy bajo en la solicitud de prestamos de personas viudas.

# %% [markdown]
# ##Diagrama de caja donde muestra una distribucion del monto de prestamo segun los solicitantes (1VAR)

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.boxplot(df_prestamos.LoanAmount)
ax.set_title('Distribución del monto del prestamo')
ax.set_xlabel('Solicitantes')
ax.set_ylabel('Monto del prestamo')
plt.show()

# %% [markdown]
# La mayoría de los préstamos se concentran en un rango moderado de alrededor de 25,000 a 75,000, pero hay varios casos de préstamos considerablemente mayores, lo que genera una distribución asimétrica hacia la derecha. Esto podría ser relevante para entender los diferentes perfiles de clientes y ajustar estrategias de financiamiento o evaluación de riesgos.

# %% [markdown]
# #Grafico de torta donde representa la distribucion de los estados civiles de los clientes (1VAR)

# %%
fig, ax = plt.subplots(figsize=(10, 7))
LoanApproved = df_prestamos['LoanApproved'].value_counts()
ax.pie(LoanApproved, labels=LoanApproved.index, autopct='%1.1f%%', startangle=90)
ax.set_title('Proporcion de prestamos aprobados y rechazados')
plt.show()

# %% [markdown]
# Este grafico de tortas representa la proporcion de cuantos fueron los prestamos aprobados (0) y cuantos rechazados (1). Hay una diferencia significante entre estos resultados ya que varian demasiado

# %% [markdown]
# #Grafico de barras donde representa la distribucion de los niveles de educacion alcanzado por los clientes (1VAR)

# %%
fig, ax = plt.subplots(figsize=(8, 4))
EducationLevel = df_prestamos['EducationLevel'].value_counts()
ax.bar(EducationLevel.index, EducationLevel.values)
ax.set_title('Distribución del nivel de educación')
ax.set_xlabel('Tipo de educacion')
ax.set_ylabel('Cantidad de personas')
plt.show()

# %% [markdown]
# Los solicitantes con educación de Bachelor (Licenciatura) y High School (Escuela secundaria) son los más numerosos. Esto indica que la mayor parte de los solicitantes se encuentra en estos niveles educativos.
# Este gráfico te permite ver cómo está distribuido el nivel educativo entre los solicitantes de préstamos, lo que podría ser útil para analizar si hay diferencias en las características de los préstamos solicitados según la educación de los clientes (como montos, plazos, tasas de interés, etc.).

# %%
import pandas as pd

# Intentar convertir la columna ApplicationDate a datetime
df_prestamos['ApplicationDate'] = pd.to_datetime(df_prestamos['ApplicationDate'], errors='coerce')

# Verificar si hay valores NaT (fechas no válidas)
print(df_prestamos['ApplicationDate'].isna().sum(), "fechas inválidas encontradas")
# Out:
# 0 fechas inválidas encontradas

# %%
# Eliminar las filas con fechas inválidas (NaT)
df_prestamos = df_prestamos.dropna(subset=['ApplicationDate'])

# %%
# Realiza el conteo de solicitudes por año
conteo_anios = df_prestamos['ApplicationDate'].dt.year.value_counts().sort_index()
conteo_anios
# Out:
# ApplicationDate
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023    365
# 2024    366
# 2025    365
# 2026    365
# 2027    365
# 2028    366
# 2029    365
# 2030    365
# 2031    365
# 2032    366
# 2033    365
# 2034    365
# 2035    365
# 2036    366
# 2037    365
# 2038    365
# 2039    365
# 2040    366
# 2041    365
# 2042    365
# 2043    365
# 2044    366
# 2045    365
# 2046    365
# 2047    365
# 2048    366
# 2049    365
# 2050    365
# 2051    365
# 2052    366
# 2053    365
# 2054    365
# 2055    365
# 2056    366
# 2057    365
# 2058    365
# 2059    365
# 2060    366
# 2061    365
# 2062    365
# 2063    365
# 2064    366
# 2065    365
# 2066    365
# 2067    365
# 2068    366
# 2069    365
# 2070    365
# 2071    365
# 2072    277
# Name: count, dtype: int64

# %%
x = conteo_anios.index
y = conteo_anios.values
x
# Out:
# Index([2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029,
#        2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041,
#        2042, 2043, 2044, 2045, 2046, 2047, 2048, 2049, 2050, 2051, 2052, 2053,
#        2054, 2055, 2056, 2057, 2058, 2059, 2060, 2061, 2062, 2063, 2064, 2065,
#        2066, 2067, 2068, 2069, 2070, 2071, 2072],
#       dtype='int32', name='ApplicationDate')

# %%
y
# Out:
# array([365, 365, 366, 365, 365, 365, 366, 365, 365, 365, 366, 365, 365,
#        365, 366, 365, 365, 365, 366, 365, 365, 365, 366, 365, 365, 365,
#        366, 365, 365, 365, 366, 365, 365, 365, 366, 365, 365, 365, 366,
#        365, 365, 365, 366, 365, 365, 365, 366, 365, 365, 365, 366, 365,
#        365, 365, 277])

# %% [markdown]
# ##Grafico de lineas donde muestra la variacion de cantidad de solicitudes de prestamos por años

# %%
fig, ax = plt.subplots(figsize=(15, 6 ))
ax.plot(x, y, marker='o')
ax.set_title('Cantidad de solicitudes por año')
ax.set_xlabel('Año')
ax.set_ylabel('Cantidad de solicitudes')
plt.show()

# %% [markdown]
# ##Grafico de lineas donde muestra la relacion entre la edad de los clientes y el monto promedio del prestamo solicitado (2VAR)

# %%
age_loan_trend = df_prestamos.groupby('Age')['LoanAmount'].mean()
plt.figure(figsize=(12, 6))
age_loan_trend.plot(kind='line', marker='o')
plt.title('Monto de Préstamo Promedio según Edad')
plt.xlabel('Edad')
plt.ylabel('Monto de Préstamo Promedio')
plt.grid()
plt.show()

# %% [markdown]
# Después de los 60 años, se aprecia una mayor variabilidad en los montos de los préstamos, con algunos picos y caídas bruscas. Esto podría indicar que, en edades más avanzadas, hay una mayor dispersión en las necesidades o capacidades de préstamo, posiblemente influenciada por factores como la jubilación o cambios en la situación económica.

# %% [markdown]
# ##Grafico de barras apiladas donde muestra la cantidad de prestamos solicitados segun el estado civil y el proposito de cada uno (3VAR)

# %%
bar_data = df_prestamos.groupby(['MaritalStatus', 'LoanPurpose']).size().unstack(fill_value=0)
fig, ax = plt.subplots(figsize=(10, 6))
bar_data.plot(kind='bar', ax=ax, stacked=False)
ax.set_title('Cantidad de Préstamos por Estado Civil y Propósito del Préstamo')
ax.set_xlabel('Estado Civil')
ax.set_ylabel('Cantidad de Préstamos')
ax.legend(title='Propósito del Préstamo')
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# ##Histograma donde se representa la distribucion de proporcion Deuda - Ingresos (RATIO) (1VAR)

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_prestamos['DebtToIncomeRatio'], bins=30, kde=True)
plt.title('Distribución de la Proporción de Deuda a Ingresos')
plt.xlabel('Proporción de Deuda a Ingresos')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# La mayor parte de los datos se concentran en los valores bajos de la proporción deuda/ingresos, entre 0.0 y 0.3, lo cual puede indicar que muchas personas mantienen una deuda baja en relación con sus ingresos. Después de aproximadamente 0.3 en la proporción de deuda a ingresos, hay una caída gradual en la frecuencia, lo que muestra que menos personas tienen una proporción deuda/ingresos más alta.

# %% [markdown]
# ##Diagrama de caja donde muestra la distribucin de ingresos anuales por el estado laboral (2VAR)

# %%
sns.boxplot(x='EmploymentStatus', y='AnnualIncome', data=df_prestamos)
plt.title('Distribución de ingresos anuales por estado laboral')
plt.xlabel('Estado laboral')
plt.ylabel('Ingreso anual')
plt.show()

# %% [markdown]
# Los empleados tienden a tener una mayor mediana de ingresos anuales en comparacion con los autonomos y los desempleados.
# Estos ultimos tienen una mediana de ingresos mas baja que los otros dos grupos, pero algunos outliers tienen ingresos inusualmente altos, lo que podria representar un error en los datos o ingresos provenientes de otras fuentes.

# %% [markdown]
# ##Grafico de violin que representa la distribucion de puntuaciones de credito segun la aprobacion del prestamo (2VAR)

# %%
sns.violinplot(x='LoanApproved', y='CreditScore', data=df_prestamos)
plt.title('Distribución de Puntuaciones de Crédito según Aprobación de Préstamo')
plt.xlabel('Aprobación de Préstamo')
plt.ylabel('Puntuación de Crédito')
plt.show()

# %% [markdown]
# Las personas con puntuaciones de crédito más *bajas* son rechazadas con mayor frecuencia, mientras que aquellas con puntuaciones de crédito más *altas* tienden a ver sus préstamos *aprobados*. Esto sugiere que la puntuación de crédito sigue siendo un factor determinante en la decisión de aprobar o rechazar una solicitud de préstamo.

# %% [markdown]
# ##Grafico de dispersion donde muestra la relacion entre ingreso anual y el monto del prestamo de cada solicitante

# %%
sns.scatterplot(x=df_prestamos['AnnualIncome'], y=df_prestamos['LoanAmount'])
plt.title('Relación entre Ingreso Anual y Monto del Préstamo')
plt.xlabel('Ingreso Anual')
plt.ylabel('Monto del Préstamo')
plt.show()

# %% [markdown]
# En este grafico podemos observar una gran aglomeracion en lo que seria menos de 20.000usd anuales como ingreso hasta los 150.000usd. Es notable que aquellas personas que tiene un ingreso anual por debajo de los 100.000usd es la mayoria en los solicitantes del presstamo. Podemos notar unos puntos inusuales (ingreso bajo y monto del prestamo alto), esto puede deberse a un error en la entrada del dato o simplemente situaciones personales de cada solicitante.

# %% [markdown]
# #Entrega final

# %% [markdown]
# ####Este proyecto es de aprendizaje supervisado porque se utiliza una variable objetivo conocida, llamada LoanApproved, que indica si un préstamo fue aprobado (0) o rechazado (1). El objetivo es que el modelo aprenda la relación entre las características del cliente (como CreditScore o AnnualIncome) y la aprobación del préstamo para poder predecir nuevos casos. En este tipo de problemas, el modelo se entrena con ejemplos donde tanto las características como el resultado son conocidos, lo que permite que aprenda a identificar patrones. Como la variable objetivo es binaria (aprobado o no aprobado), estamos ante un caso de clasificación supervisada.

# %%
#importamos librerias
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
X = df_prestamos.drop(columns='LoanApproved')
y = df_prestamos['LoanApproved']

# %%
X
# Out:
#       ApplicationDate  Age  AnnualIncome  CreditScore EmploymentStatus  \
# 0          2018-01-01   45         39948          617         Employed
# 1          2018-01-02   38         39709          628         Employed
# 2          2018-01-03   47         40724          570         Employed
# 3          2018-01-04   58         69084          545         Employed
# 4          2018-01-05   37        103264          594         Employed
# ...               ...  ...           ...          ...              ...
# 19995      2072-09-29   44         30180          587         Employed
# 19996      2072-09-30   56         49246          567         Employed
# 19997      2072-10-01   44         48958          645         Employed
# 19998      2072-10-02   60         41025          560         Employed
# 19999      2072-10-03   20         53227          574         Employed
#
#       EducationLevel  Experience  LoanAmount  LoanDuration MaritalStatus  ...  \
# 0             Master          22       13152            48       Married  ...
# 1          Associate          15       26045            48        Single  ...
# 2           Bachelor          26       17627            36       Married  ...
# 3        High School          34       37898            96        Single  ...
# 4          Associate          17        9184            36       Married  ...
# ...              ...         ...         ...           ...           ...  ...
# 19995    High School          19       24521            36       Married  ...
# 19996      Associate          33       25818            36       Married  ...
# 19997       Bachelor          20       37033            72       Married  ...
# 19998    High School          36       14760            72       Married  ...
# 19999      Associate           0       32055            48       Married  ...
#
#        TotalLiabilities MonthlyIncome  UtilityBillsPaymentHistory  JobTenure  \
# 0                 19183   3329.000000                    0.724972         11
# 1                  9595   3309.083333                    0.935132          3
# 2                128874   3393.666667                    0.872241          6
# 3                  5370   5757.000000                    0.896155          5
# 4                 17286   8605.333333                    0.941369          5
# ...                 ...           ...                         ...        ...
# 19995             25642   2515.000000                    0.826217          1
# 19996              5569   4103.833333                    0.816618          3
# 19997              4653   4079.833333                    0.887216          3
# 19998             11485   3418.750000                    0.843787          5
# 19999             41636   4435.583333                    0.853801          5
#
#        NetWorth  BaseInterestRate  InterestRate  MonthlyLoanPayment  \
# 0        126928          0.199652      0.227590          419.805992
# 1         43609          0.207045      0.201077          794.054238
# 2          5205          0.217627      0.212548          666.406688
# 3         99452          0.300398      0.300911         1047.506980
# 4        227019          0.197184      0.175990          330.179140
# ...         ...               ...           ...                 ...
# 19995     55327          0.216021      0.195574          905.767712
# 19996     64002          0.227318      0.199168          958.395633
# 19997    103663          0.229533      0.226766          945.427454
# 19998     10600          0.249760      0.264873          411.168284
# 19999     41372          0.240055      0.242693         1049.830407
#
#       TotalDebtToIncomeRatio  RiskScore
# 0                   0.181077       49.0
# 1                   0.389852       52.0
# 2                   0.462157       52.0
# 3                   0.313098       54.0
# 4                   0.070210       36.0
# ...                      ...        ...
# 19995               0.627741       55.0
# 19996               0.334418       54.0
# 19997               0.357227       45.0
# 19998               0.408678       59.0
# 19999               0.298006       59.0
#
# [20000 rows x 35 columns]

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 19995    0
# 19996    0
# 19997    0
# 19998    0
# 19999    0
# Name: LoanApproved, Length: 20000, dtype: int64

# %%
X = pd.get_dummies(X, drop_first=True) #Convierto las variables caregorias a numericas para poder trabajar con el modelo

# %%
X
# Out:
#       ApplicationDate  Age  AnnualIncome  CreditScore  Experience  LoanAmount  \
# 0          2018-01-01   45         39948          617          22       13152
# 1          2018-01-02   38         39709          628          15       26045
# 2          2018-01-03   47         40724          570          26       17627
# 3          2018-01-04   58         69084          545          34       37898
# 4          2018-01-05   37        103264          594          17        9184
# ...               ...  ...           ...          ...         ...         ...
# 19995      2072-09-29   44         30180          587          19       24521
# 19996      2072-09-30   56         49246          567          33       25818
# 19997      2072-10-01   44         48958          645          20       37033
# 19998      2072-10-02   60         41025          560          36       14760
# 19999      2072-10-03   20         53227          574           0       32055
#
#        LoanDuration  NumberOfDependents  MonthlyDebtPayments  \
# 0                48                   2                  183
# 1                48                   1                  496
# 2                36                   2                  902
# 3                96                   1                  755
# 4                36                   1                  274
# ...             ...                 ...                  ...
# 19995            36                   3                  673
# 19996            36                   5                  414
# 19997            72                   3                  512
# 19998            72                   3                  986
# 19999            48                   0                  272
#
#        CreditCardUtilizationRate  ...  MaritalStatus_Married  \
# 0                       0.354418  ...                   True
# 1                       0.087827  ...                  False
# 2                       0.137414  ...                   True
# 3                       0.267587  ...                  False
# 4                       0.320535  ...                   True
# ...                          ...  ...                    ...
# 19995                   0.101288  ...                   True
# 19996                   0.471818  ...                   True
# 19997                   0.216596  ...                   True
# 19998                   0.364758  ...                   True
# 19999                   0.536411  ...                   True
#
#        MaritalStatus_Single  MaritalStatus_Widowed  HomeOwnershipStatus_Other  \
# 0                     False                  False                      False
# 1                      True                  False                      False
# 2                     False                  False                      False
# 3                      True                  False                      False
# 4                     False                  False                      False
# ...                     ...                    ...                        ...
# 19995                 False                  False                      False
# 19996                 False                  False                      False
# 19997                 False                  False                      False
# 19998                 False                  False                      False
# 19999                 False                  False                      False
#
#        HomeOwnershipStatus_Own  HomeOwnershipStatus_Rent  \
# 0                         True                     False
# 1                        False                     False
# 2                        False                      True
# 3                        False                     False
# 4                        False                     False
# ...                        ...                       ...
# 19995                    False                      True
# 19996                    False                      True
# 19997                    False                     False
# 19998                     True                     False
# 19999                     True                     False
#
#        LoanPurpose_Debt Consolidation  LoanPurpose_Education  \
# 0                               False                  False
# 1                                True                  False
# 2                               False                   True
# 3                               False                  False
# 4                                True                  False
# ...                               ...                    ...
# 19995                           False                  False
# 19996                            True                  False
# 19997                           False                  False
# 19998                            True                  False
# 19999                           False                  False
#
#        LoanPurpose_Home  LoanPurpose_Other
# 0                  True              False
# 1                 False              False
# 2                 False              False
# 3                  True              False
# 4                 False              False
# ...                 ...                ...
# 19995             False              False
# 19996             False              False
# 19997              True              False
# 19998             False              False
# 19999             False               True
#
# [20000 rows x 46 columns]

# %%
print(X.dtypes)
# Out:
# ApplicationDate                   datetime64[ns]
# Age                                        int64
# AnnualIncome                               int64
# CreditScore                                int64
# Experience                                 int64
# LoanAmount                                 int64
# LoanDuration                               int64
# NumberOfDependents                         int64
# MonthlyDebtPayments                        int64
# CreditCardUtilizationRate                float64
# NumberOfOpenCreditLines                    int64
# NumberOfCreditInquiries                    int64
# DebtToIncomeRatio                        float64
# BankruptcyHistory                          int64
# PreviousLoanDefaults                       int64
# PaymentHistory                             int64
# LengthOfCreditHistory                      int64
# SavingsAccountBalance                      int64
# CheckingAccountBalance                     int64
# TotalAssets                                int64
# TotalLiabilities                           int64
# MonthlyIncome                            float64
# UtilityBillsPaymentHistory               float64
# JobTenure                                  int64
# NetWorth                                   int64
# BaseInterestRate                         float64
# InterestRate                             float64
# MonthlyLoanPayment                       float64
# TotalDebtToIncomeRatio                   float64
# RiskScore                                float64
# EmploymentStatus_Self-Employed              bool
# EmploymentStatus_Unemployed                 bool
# EducationLevel_Bachelor                     bool
# EducationLevel_Doctorate                    bool
# EducationLevel_High School                  bool
# EducationLevel_Master                       bool
# MaritalStatus_Married                       bool
# MaritalStatus_Single                        bool
# MaritalStatus_Widowed                       bool
# HomeOwnershipStatus_Other                   bool
# HomeOwnershipStatus_Own                     bool
# HomeOwnershipStatus_Rent                    bool
# LoanPurpose_Debt Consolidation              bool
# LoanPurpose_Education                       bool
# LoanPurpose_Home                            bool
# LoanPurpose_Other                           bool
# dtype: object

# %%
# Elimino la columna ApplicationDate por el tipo de dato
X = X.drop(columns=['ApplicationDate'])

# %%
# Reviso los tipos de datos después de eliminar la columna para corroborar
print(X.dtypes)
# Out:
# Age                                 int64
# AnnualIncome                        int64
# CreditScore                         int64
# Experience                          int64
# LoanAmount                          int64
# LoanDuration                        int64
# NumberOfDependents                  int64
# MonthlyDebtPayments                 int64
# CreditCardUtilizationRate         float64
# NumberOfOpenCreditLines             int64
# NumberOfCreditInquiries             int64
# DebtToIncomeRatio                 float64
# BankruptcyHistory                   int64
# PreviousLoanDefaults                int64
# PaymentHistory                      int64
# LengthOfCreditHistory               int64
# SavingsAccountBalance               int64
# CheckingAccountBalance              int64
# TotalAssets                         int64
# TotalLiabilities                    int64
# MonthlyIncome                     float64
# UtilityBillsPaymentHistory        float64
# JobTenure                           int64
# NetWorth                            int64
# BaseInterestRate                  float64
# InterestRate                      float64
# MonthlyLoanPayment                float64
# TotalDebtToIncomeRatio            float64
# RiskScore                         float64
# EmploymentStatus_Self-Employed       bool
# EmploymentStatus_Unemployed          bool
# EducationLevel_Bachelor              bool
# EducationLevel_Doctorate             bool
# EducationLevel_High School           bool
# EducationLevel_Master                bool
# MaritalStatus_Married                bool
# MaritalStatus_Single                 bool
# MaritalStatus_Widowed                bool
# HomeOwnershipStatus_Other            bool
# HomeOwnershipStatus_Own              bool
# HomeOwnershipStatus_Rent             bool
# LoanPurpose_Debt Consolidation       bool
# LoanPurpose_Education                bool
# LoanPurpose_Home                     bool
# LoanPurpose_Other                    bool
# dtype: object

# %% [markdown]
# Regresion Logistica

# %%
#Separamos train/test

#Prueba del 30% de filas
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
model = LogisticRegression(max_iter=100000, n_jobs=-1)

model.fit(X_train, y_train)


predicciones = model.predict(X_test)
predicciones
# Out:
# array([1, 1, 0, ..., 0, 0, 1])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred=predicciones, y_true=y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      4522
#            1       0.94      0.93      0.94      1478
#
#     accuracy                           0.97      6000
#    macro avg       0.96      0.96      0.96      6000
# weighted avg       0.97      0.97      0.97      6000

# %%
# Comprobar tipos de datos en el DataFrame
print(df_prestamos.dtypes)
# Out:
# ApplicationDate               datetime64[ns]
# Age                                    int64
# AnnualIncome                           int64
# CreditScore                            int64
# EmploymentStatus                      object
# EducationLevel                        object
# Experience                             int64
# LoanAmount                             int64
# LoanDuration                           int64
# MaritalStatus                         object
# NumberOfDependents                     int64
# HomeOwnershipStatus                   object
# MonthlyDebtPayments                    int64
# CreditCardUtilizationRate            float64
# NumberOfOpenCreditLines                int64
# NumberOfCreditInquiries                int64
# DebtToIncomeRatio                    float64
# BankruptcyHistory                      int64
# LoanPurpose                           object
# PreviousLoanDefaults                   int64
# PaymentHistory                         int64
# LengthOfCreditHistory                  int64
# SavingsAccountBalance                  int64
# CheckingAccountBalance                 int64
# TotalAssets                            int64
# TotalLiabilities                       int64
# MonthlyIncome                        float64
# UtilityBillsPaymentHistory           float64
# JobTenure                              int64
# NetWorth                               int64
# BaseInterestRate                     float64
# InterestRate                         float64
# MonthlyLoanPayment                   float64
# TotalDebtToIncomeRatio               float64
# LoanApproved                           int64
# RiskScore                            float64
# dtype: object

# %%
#analizamos la precision
print(accuracy_score(y_test, predicciones))
# Out:
# 0.9698333333333333

# %% [markdown]
# Se obtuvo una precision muy buena del 98,7% de las predicciones

# %%
from sklearn.metrics import confusion_matrix
#Matriz de confusion
cf_matrix = confusion_matrix(y_test, predicciones)
import seaborn as sns
ax = sns.heatmap(cf_matrix, annot=True, cmap='Blues')
ax.set_title('Matriz de confusion R-L');
ax.set_xlabel('\nValores predichos')
ax.set_ylabel('Valores reales ');
## Ticket labels - En orden alfabetico
ax.xaxis.set_ticklabels(['Aprobado','Rechazado'])
ax.yaxis.set_ticklabels(['Aprobado','Rechazado'])
plt.show()

# %% [markdown]
# Esta matriz de confusion nos muestra que 4400 de los prestamos fueron aprobados (valor real) y el modelo predijo correctamente que serian aprobados.
# 84 fueron los prestamos aprobados en realidad pero el modelo predijo que serian rechazados.
# 97 fueron los prestamos que en realidad fueron rechazados pero el modelo predijo que serian aprobados, esto es una complicacion porque el modelo aprueba prestamos a personas que no cumplen con los criterios.
# 1400 fueron los prestamos que en realidad fueron rechazados y el modelo predijo correctamente su rechazo.

# %% [markdown]
# ##Utilizamos k-NN

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred=predicciones, y_true=y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      4522
#            1       0.94      0.93      0.94      1478
#
#     accuracy                           0.97      6000
#    macro avg       0.96      0.96      0.96      6000
# weighted avg       0.97      0.97      0.97      6000

# %%
KNN = KNeighborsClassifier(n_neighbors=5)


KNN.fit(X_train, y_train)


y_pred = KNN.predict(X_test)

# %%
# Crear la matriz de confusión
matriz_c= confusion_matrix(y_test, y_pred)

# Imprimir la matriz de confusión
print("Matriz de confusión:")
print(matriz_c)

g = sns.heatmap(matriz_c, annot=True, cmap='Reds')
g.set(title='Matriz de confusión KNN', ylabel ='Valor real', xlabel='Predicción')
g.set_xticklabels(['Aprobado', 'Rechazado'])
g.set_yticklabels(['Aprobado', 'Rechazado'])
# Out:
# Matriz de confusión:
# [[4192  330]
#  [ 505  973]]
# [Text(0, 0.5, 'Aprobado'), Text(0, 1.5, 'Rechazado')]

# %% [markdown]
# Esta matriz de confusion nos muestra que 4200 de los prestamos fueron aprobados (valor real) y el modelo predijo correctamente que serian aprobados.
# 330 fueron los prestamos aprobados en realidaD pero el modelo predijo que serian rechazados.
# 500 fueron los prestamos que en realidad fueron rechazados pero el modelo predijo que serian aprobados, esto es una complicacion porque el modelo aprueba prestamos a personas que no cumplen con los criterios.
# 970 fueron los prestamos que en realidad fueron rechazados y el modelo predijo correctamente su rechazo.

# %%
#Reduccion de dimension

# %%
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import scale
import statsmodels.api as sm

# %%
print(df_prestamos.info())  # Esto te mostrará el tipo de cada columna
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 46 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             20000 non-null  int64
#  1   AnnualIncome                    20000 non-null  int64
#  2   CreditScore                     20000 non-null  int64
#  3   Experience                      20000 non-null  int64
#  4   LoanAmount                      20000 non-null  int64
#  5   LoanDuration                    20000 non-null  int64
#  6   NumberOfDependents              20000 non-null  int64
#  7   MonthlyDebtPayments             20000 non-null  int64
#  8   CreditCardUtilizationRate       20000 non-null  float64
#  9   NumberOfOpenCreditLines         20000 non-null  int64
#  10  NumberOfCreditInquiries         20000 non-null  int64
#  11  DebtToIncomeRatio               20000 non-null  float64
#  12  BankruptcyHistory               20000 non-null  int64
#  13  PreviousLoanDefaults            20000 non-null  int64
#  14  PaymentHistory                  20000 non-null  int64
#  15  LengthOfCreditHistory           20000 non-null  int64
#  16  SavingsAccountBalance           20000 non-null  int64
#  17  CheckingAccountBalance          20000 non-null  int64
#  18  TotalAssets                     20000 non-null  int64
#  19  TotalLiabilities                20000 non-null  int64
#  20  MonthlyIncome                   20000 non-null  float64
#  21  UtilityBillsPaymentHistory      20000 non-null  float64
#  22  JobTenure                       20000 non-null  int64
#  23  NetWorth                        20000 non-null  int64
#  24  BaseInterestRate                20000 non-null  float64
#  25  InterestRate                    20000 non-null  float64
#  26  MonthlyLoanPayment              20000 non-null  float64
#  27  TotalDebtToIncomeRatio          20000 non-null  float64
#  28  LoanApproved                    20000 non-null  int64
#  29  RiskScore                       20000 non-null  float64
#  30  EmploymentStatus_Self-Employed  20000 non-null  bool
#  31  EmploymentStatus_Unemployed     20000 non-null  bool
#  32  EducationLevel_Bachelor         20000 non-null  bool
#  33  EducationLevel_Doctorate        20000 non-null  bool
#  34  EducationLevel_High School      20000 non-null  bool
#  35  EducationLevel_Master           20000 non-null  bool
#  36  MaritalStatus_Married           20000 non-null  bool
#  37  MaritalStatus_Single            20000 non-null  bool
#  38  MaritalStatus_Widowed           20000 non-null  bool
#  39  HomeOwnershipStatus_Other       20000 non-null  bool
#  40  HomeOwnershipStatus_Own         20000 non-null  bool
#  41  HomeOwnershipStatus_Rent        20000 non-null  bool
#  42  LoanPurpose_Debt Consolidation  20000 non-null  bool
#  43  LoanPurpose_Education           20000 non-null  bool
#  44  LoanPurpose_Home                20000 non-null  bool
#  45  LoanPurpose_Other               20000 non-null  bool
# dtypes: bool(16), float64(9), int64(21)
# memory usage: 4.9 MB
# None

# %%
# Mostrar las columnas categóricas
categorical_columns = df_prestamos.select_dtypes(include=['object']).columns
print("Columnas categóricas:", categorical_columns)
# Out:
# Columnas categóricas: Index([], dtype='object')

# %%
# Convertir columnas categóricas
df_prestamos = pd.get_dummies(df_prestamos, columns=categorical_columns, drop_first=True)

# %%
print(df_prestamos.info())  # corroborar
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 46 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             20000 non-null  int64
#  1   AnnualIncome                    20000 non-null  int64
#  2   CreditScore                     20000 non-null  int64
#  3   Experience                      20000 non-null  int64
#  4   LoanAmount                      20000 non-null  int64
#  5   LoanDuration                    20000 non-null  int64
#  6   NumberOfDependents              20000 non-null  int64
#  7   MonthlyDebtPayments             20000 non-null  int64
#  8   CreditCardUtilizationRate       20000 non-null  float64
#  9   NumberOfOpenCreditLines         20000 non-null  int64
#  10  NumberOfCreditInquiries         20000 non-null  int64
#  11  DebtToIncomeRatio               20000 non-null  float64
#  12  BankruptcyHistory               20000 non-null  int64
#  13  PreviousLoanDefaults            20000 non-null  int64
#  14  PaymentHistory                  20000 non-null  int64
#  15  LengthOfCreditHistory           20000 non-null  int64
#  16  SavingsAccountBalance           20000 non-null  int64
#  17  CheckingAccountBalance          20000 non-null  int64
#  18  TotalAssets                     20000 non-null  int64
#  19  TotalLiabilities                20000 non-null  int64
#  20  MonthlyIncome                   20000 non-null  float64
#  21  UtilityBillsPaymentHistory      20000 non-null  float64
#  22  JobTenure                       20000 non-null  int64
#  23  NetWorth                        20000 non-null  int64
#  24  BaseInterestRate                20000 non-null  float64
#  25  InterestRate                    20000 non-null  float64
#  26  MonthlyLoanPayment              20000 non-null  float64
#  27  TotalDebtToIncomeRatio          20000 non-null  float64
#  28  LoanApproved                    20000 non-null  int64
#  29  RiskScore                       20000 non-null  float64
#  30  EmploymentStatus_Self-Employed  20000 non-null  bool
#  31  EmploymentStatus_Unemployed     20000 non-null  bool
#  32  EducationLevel_Bachelor         20000 non-null  bool
#  33  EducationLevel_Doctorate        20000 non-null  bool
#  34  EducationLevel_High School      20000 non-null  bool
#  35  EducationLevel_Master           20000 non-null  bool
#  36  MaritalStatus_Married           20000 non-null  bool
#  37  MaritalStatus_Single            20000 non-null  bool
#  38  MaritalStatus_Widowed           20000 non-null  bool
#  39  HomeOwnershipStatus_Other       20000 non-null  bool
#  40  HomeOwnershipStatus_Own         20000 non-null  bool
#  41  HomeOwnershipStatus_Rent        20000 non-null  bool
#  42  LoanPurpose_Debt Consolidation  20000 non-null  bool
#  43  LoanPurpose_Education           20000 non-null  bool
#  44  LoanPurpose_Home                20000 non-null  bool
#  45  LoanPurpose_Other               20000 non-null  bool
# dtypes: bool(16), float64(9), int64(21)
# memory usage: 4.9 MB
# None

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline


pca_pipeline = make_pipeline(StandardScaler(), PCA())
pca_pipeline.fit(X)
componentes_principales = pca_pipeline.transform(X)

#Crear un DataFrame para los componentes principales
df_componentes = pd.DataFrame(componentes_principales, columns=[f'Componente_{i+1}' for i in range(componentes_principales.shape[1])])
#Ver el porcentaje de varianza explicada por cada componente
modelo_pca = pca_pipeline.named_steps['pca']
print('Porcentaje de varianza explicada por cada componente:')
print(modelo_pca.explained_variance_ratio_)
# Gráfico de dispersión de los dos primeros componentes principales
plt.figure(figsize=(10, 6))
plt.scatter(df_componentes['Componente_1'], df_componentes['Componente_2'], alpha=0.6)
plt.title('Gráfico de Dispersión de los dos Primeros Componentes Principales')
plt.xlabel('Componente Principal 1')
plt.ylabel('Componente Principal 2')
plt.grid()
plt.show()
# Out:
# Porcentaje de varianza explicada por cada componente:
# [0.08273216 0.05508015 0.04757828 0.04497723 0.03893979 0.03717947
#  0.03159901 0.03075346 0.02978524 0.02929151 0.02752238 0.02729788
#  0.02569056 0.02528777 0.02456204 0.02407374 0.02389228 0.02318397
#  0.02291426 0.02277978 0.02256779 0.02248877 0.02231842 0.02220604
#  0.02210088 0.02186805 0.02184559 0.02167815 0.02166736 0.02150257
#  0.02132561 0.01997153 0.01748718 0.01143401 0.00608116 0.00597164
#  0.00579091 0.00532426 0.00495366 0.00283511 0.0025849  0.00037741
#  0.00027573 0.00022227 0.        ]
